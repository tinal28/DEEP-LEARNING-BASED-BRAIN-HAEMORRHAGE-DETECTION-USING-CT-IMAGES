# %%
! pip install ultralytics
! pip install wandb

# %%
from ultralytics import YOLO
import wandb

wandb.login(key='8c024b6220795e8ed27faba245ccbec5cfe628a9')
model = YOLO('/kaggle/input/bestpath/best.pt')
model.train(data='/kaggle/input/dtaacopyyaml/data - Copy.yaml',epochs =2)
